# %% [markdown]
# ## Modelo de distribuição de densidades e velocidades

# %%
############Pacotes################
# %matplotlib inline
import numpy as np
import pylab as py
import scipy as sp
from scipy.interpolate import griddata
import math as mt
import matplotlib.pyplot as plt
from IPython.display import Latex
####################################

# %%
vel = np.loadtxt("velocidades.txt")
print(vel)
# Out:
# [[1.00e+00 1.00e+00 1.50e+03]
#  [1.00e+00 2.00e+00 1.50e+03]
#  [1.00e+00 3.00e+00 1.50e+03]
#  ...
#  [3.02e+02 6.00e+02 5.00e+03]
#  [3.02e+02 6.01e+02 5.00e+03]
#  [3.02e+02 6.02e+02 5.00e+03]]

# %%
py.rcParams['figure.figsize'] = (15.0, 8.0)#Redimensiona a figura

x=vel[:,0].reshape((302,602))#o reshape recebe o nx e nz do modelo
y=vel[:,1].reshape((302,602))
z=vel[:,2].reshape((302,602))


plt.pcolor(y,x,z)

plt.show()
